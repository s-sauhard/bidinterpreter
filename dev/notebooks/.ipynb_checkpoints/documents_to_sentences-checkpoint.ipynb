# %%
import pandas as pd, numpy as np
import os, glob, re, sys, time
sys.path.append("..")

from project.apps.bidinterpreter.doctools import DocTools
from tqdm.notebook import tqdm
from nltk import sent_tokenize, download

# %matplotlib inline

# %% [markdown]
# ### Setting up the "punkt" nltk punctuation tool for breaking text into a list of sentences.
#
# Only need to do this 1x.

# %%
download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/dave/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !conda install -c conda-forge ipywidgets --yes

# %% [markdown]
# ## Loading Text into DataFrame
#
# Prior to running this notebook, the `matching_performance_stats` notebook must be run which creates the "searchable" PDF version of the original PDF documents.  This bit of code will load each file by index, name, and original text.  The end goal of this notebook is to produce a list of sentences with their cooresponding documents.

# %%
dt = DocTools(use_django_paths = False)  # this is the new class for general document handling which may be expanded to more than just "PDFs"

pdf_directory = "processed/*.pdf.png.processed.pdf"
source_path   = f"{os.getcwd()}/processed"

filtered = [
    (index, file) for index, file in enumerate(glob.iglob(pdf_directory, recursive=True)) # find all files in uploads directory
    #if re.findall(".+", file) and "png" not in file         # filter to files with pdf extension but not having the PNG files (original, unprocessed docs)
]

docs = []
for index, doc in filtered:
    print(f"Processing ({index + 1}/{len(filtered)}) {doc}...")
    text, vocabulary = dt.pdf_to_text_coordinates(doc)
    docs.append(dict(
        document_index = index,
        document   = doc.split("/")[::-1][0], # get only the docname
        text       = text,
        vocabulary = vocabulary
    ))

df = pd.DataFrame(docs)
# Out:
# setting use_django_paths False
# Processing (1/338) processed/010 400 Divisadero SHAC LOI 09.10.18.pdf.png.processed.pdf...
# Processing (2/338) processed/010 AvalonBay LOI - Gateway - 2019-11-7.pdf.png.processed.pdf...
# Processing (3/338) processed/010 Cambridge Capital LOI 2016-04-07.pdf.png.processed.pdf...
# Processing (4/338) processed/010 DR Horton LOI Crescent Heights 2017-11-1.pdf.png.processed.pdf...
# Processing (5/338) processed/010 Dutchints LOI 2018-11-17.pdf.png.processed.pdf...
# Processing (6/338) processed/010 Fairfield - Summit at Lime Ridge LOI 2018-4-26.pdf.png.processed.pdf...
# Processing (7/338) processed/010 Fairfield LOI - 10-18-11.pdf.png.processed.pdf...
# Processing (8/338) processed/010 Greystar LOI 2018-9-25.pdf.png.processed.pdf...
# Processing (9/338) processed/010 JDA LOI 2013-4-25.pdf.png.processed.pdf...
# Processing (10/338) processed/010 MCRT LOI_400 Divis final.pdf.png.processed.pdf...
# Processing (11/338) processed/010 Pulte LOI 2016-2-12.pdf.png.processed.pdf...
# Processing (12/338) processed/010 Toll Bros LOI 10-24-11.pdf.png.processed.pdf...
# Processing (13/338) processed/0100 Hanover LOI 10-17-11.pdf.png.processed.pdf...
# Processing (14/338) processed/011 Pulte LOI 2016-2-27.pdf.png.processed.pdf...
# Processing (15/338) processed/012 AvalonBay LOI - Gateway - 2019-11-18 (clean).pdf.png.processed.pdf...
# Processing (16/338) processed/012 Cambridge Capital LOI 2016-4-22.pdf.png.processed.pdf...
# Processing (17/338) processed/012 DR Horton LOI Crescent Heights 2017-11-8.pdf.png.processed.pdf...
# Processing (18/338) processed/012 JDA LOI 2013-5-30.pdf.png.processed.pdf...
# Processing (19/338) processed/012 Pulte LOI 2016-8-5.pdf.png.processed.pdf...
# Processing (118/338) processed/170217_Alameda Point 6_7_NWHM  LOI.pdf.png.processed.pdf...
# Processing (119/338) processed/180430 City Ventures LOI_Napa Creek, Napa, CA - TCR v2.pdf.png.processed.pdf...
# Processing (120/338) processed/180430 Napa Creek LOI - TCR v2.pdf.png.processed.pdf...
# Processing (121/338) processed/180510 Napa Creek LOI - FINAL - EXECUTED.pdf.png.processed.pdf...
# Processing (122/338) processed/2017-1-19 Trumark LOI.pdf.png.processed.pdf...
# Processing (123/338) processed/350 S Winchester - LOI - TMG - 2019-03-10.pdf.png.processed.pdf...
# Processing (124/338) processed/400 Divisadero Genesis LOI w Mill Creek_fully executed_021820.pdf.png.processed.pdf...
# Processing (125/338) processed/400 Divisadero LOI CLEAN_111319.pdf.png.processed.pdf...
# Processing (126/338) processed/400 Divisadero LOI redline_111319.pdf.png.processed.pdf...
# Processing (127/338) processed/400 Divisadero LOI_190111 FORE.pdf.png.processed.pdf...
# Processing (128/338) processed/400 Divisadero SHAC LOI 02.26.19.pdf.png.processed.pdf...
# Processing (129/338) processed/400 Divisadero SHAC LOI 04.03.19.pdf.png.processed.pdf...
# Processing (130/338) processed/400 Divisadero SHAC LOI 09.12.19.pdf.png.processed.pdf...
# Processing (131/338) processed/400 Divisadero_Mill Creek LOI comments_020520.pdf.png.processed.pdf...
# Processing (132/338) processed/5.4.18_Ventures LOI_Napa Creek Napa CA - CV v3.pdf.png.processed.pdf...
# Processing (133/338) processed/888 Tilden LOI final rev 1.pdf.png.processed.pdf...
# Processing (134/338) processed/888 Tilden LOI final.pdf.png.processed.pdf...
# Processing (135/338) processed/888SanMateo - BlackRock LOI - B_F 180731.pdf.png.processed.pdf...
# Processing (136/338) processed/888Tilden LOI.pdf.png.processed.pdf...
# Processing (137/338) processed/AIMCO Courtyards at 65th - LOI - 04.18.19.pdf.png.processed.pdf...
# Processing (138/338) processed/AIMCO LOI 2-22-08.pdf.png.processed.pdf...
# Processing (139/338) processed/AMLI LOI 6-3-2013.pdf.png.processed.pdf...
# Processing (140/338) processed/AMLI LOI Signed - 6-03-2013.pdf.png.processed.pdf...
# Processing (141/338) processed/AMLI LOI Signed 06 26 13.pdf.png.processed.pdf...
# Processing (142/338) processed/AREA LOI - Triton Pilgrim (2012 10 23).pdf.png.processed.pdf...
# Processing (143/338) processed/ASB Capital Management LOI - 10.30.2012.pdf.png.processed.pdf...
# Processing (144/338) processed/Abacus Villa Morada - LOI - 6.25.19.pdf.png.processed.pdf...
# Processing (145/338) processed/Acappella LOI (1-07-10).pdf.png.processed.pdf...
# Processing (146/338) processed/Acappella LOI (3-05-10).pdf.png.processed.pdf...
# Processing (147/338) processed/Aimco - Courtyards at 65th - LOI - 04.24.19.pdf.png.processed.pdf...
# Processing (148/338) processed/Archstone LOI 9-16-05.pdf.png.processed.pdf...
# Processing (149/338) processed/Aster LOI - MORE 2018-10-1.pdf.png.processed.pdf...
# Processing (150/338) processed/AvalonBay LOI.pdf.png.processed.pdf...
# Processing (151/338) processed/BRE LOI - 10.30.2012.pdf.png.processed.pdf...
# Processing
OI - 10.30.2012.pdf.png.processed.pdf...
# Processing (184/338) processed/DR Horton LOI The Heights 10.22.19.pdf.png.processed.pdf...
# Processing (185/338) processed/Dinerstein LOI - 5-28-2013.pdf.png.processed.pdf...
# Processing (186/338) processed/Dinerstein LOI 6-26-13.pdf.png.processed.pdf...
# Processing (187/338) processed/Dublin ProLogis LOI 3 14 13-signed.pdf.png.processed.pdf...
# Processing (188/338) processed/Dutchints LOI_VOLAR_350 S Winchester_4.30.19.pdf.png.processed.pdf...
# Processing (189/338) processed/EQR LOI - 02082013.pdf.png.processed.pdf...
# Processing (190/338) processed/EQR LOI 2-25-08.pdf.png.processed.pdf...
# Processing (191/338) processed/EQR LOI 2-26-08.pdf.png.processed.pdf...
# Processing (192/338) processed/EQR LOI 2013-11-6.pdf.png.processed.pdf...
# Processing (193/338) processed/EQR LOI 2013-6-10.pdf.png.processed.pdf...
# Processing (194/338) processed/EQR LOI 3-19-2008.pdf.png.processed.pdf...
# Processing (195/338) processed/EQR LOI 3-5-2008.pdf.png.processed.pdf...
# Processing (196/338) processed/EQR LOI 3-7-2008.pdf.png.processed.pdf...
# Processing (197/338) processed/EQR LOI 9-19-06.pdf.png.processed.pdf...
# Processing (198/338) processed/Empire LOI 5-8-08.pdf.png.processed.pdf...
# Processing (199/338) processed/Esprit II LOI - AMLI Residential - 06 05 13.pdf.png.processed.pdf...
# Processing (200/338) processed/Essex LOI - 11.7.2012.pdf.png.processed.pdf...
# Processing (201/338) processed/Essex LOI 9-16-05.pdf.png.processed.pdf...
# Processing (202/338) processed/FPA Villa Morada_LOI.pdf.png.processed.pdf...
# Processing (203/338) processed/Fairfield Block 11 LOI 10 23 2017.pdf.png.processed.pdf...
# Processing (204/338) processed/Fairfield LOI 5-30-08.pdf.png.processed.pdf...
# Processing (205/338) processed/Fairfield LOI 5-8-08.pdf.png.processed.pdf...
# Processing (206/338) processed/Fairfield LOI 6-3-08.pdf.png.processed.pdf...
# Processing (207/338) processed/Fairfield LOI 8-29-12.pdf.png.processed.pdf...
# Processing (208/338) processed/Fowler LOI 8-28-12.pdf.png.processed.pdf...
# Processing (209/338) processed/Fowler Properties LOI 2-22-08.pdf.png.processed.pdf...
# Processing (210/338) processed/GID LOI 2-25-08.pdf.png.processed.pdf...
# Processing (211/338) processed/Griffis - 2019.4.24 LOI Courtyards at 65th.pdf.png.processed.pdf...
# Processing (212/338) processed/Griffis 2019.4.19 LOI Courtyards at 65th.pdf.png.processed.pdf...
# Processing (213/338) processed/Grupe Villa Morada LOI 07.08.19.pdf.png.processed.pdf...
# Processing (214/338) processed/Henderson LOI 5-9-08.pdf.png.processed.pdf...
# Processing (215/338) processed/Huxley - BlackRock LOI - 02282019.pdf.png.processed.pdf...
# Processing (216/338) processed/IEC LOI - Courtyards at 65th - 4.11.19 Revised Offer.pdf.png.processed.pdf...
# Processing (217/338) processed/IEC LOI - Courtyards at 65th - 5.28.19.pdf.png.processed.pdf...
# Processing (218/338) processed/IEC LOI 8-28-12.pdf.png.processed.pdf...
# Processing (219/338) processed/IMT LOI - The Courtyards at 65th Street - 4.18.19.pdf.png.processed.pdf...
# Processing (220/338) processed/Invesco LOI - 10.30.2012.pdf.png.processed.pdf...
# Processing (221/338) processed/Invesco LOI - 11.6.2012.pdf.png.processed.pdf...
# Processing (222/338) processed/Invesco LOI 02-04-13.pdf.png.processed.pdf...
# Processing (223/338) processed/JDA West - Cottle Station LOI_6-18-13 - Executed.pdf.png.processed.pdf...
# Processing (224/338) processed/JPM LOI - 10.30.2012.pdf.png.processed.pdf...
# Processing
# Processing (333/338) processed/WP LOI 400 Divisadero 2.15.19.pdf.png.processed.pdf...
# Processing (334/338) processed/Waterford Place JPM LOI 101129.pdf.png.processed.pdf...
# Processing (335/338) processed/Waterford Place JPM LOI 101202.pdf.png.processed.pdf...
# Processing (336/338) processed/Waterford Place Signed LOI 12-15-10.pdf.png.processed.pdf...
# Processing (337/338) processed/Waterford Place UBS LOI (12.2.2010).pdf.png.processed.pdf...
# Processing (338/338) processed/Waterton LOI 8-28-12.pdf.png.processed.pdf...

# %% [markdown]
# ### Convert Raw Text to Series of Sentences

# %%
def text_to_sentences(row):
    sentences = sent_tokenize(row['text'])
    expanded = []
    for sentence in sentences:
        expanded.append(dict(
            document_index = row['document_index'],
            document = row['document'],
            sentence = sentence,
            target_class   = np.nan
        ))
    return expanded
preformatted = df.apply(text_to_sentences, axis = 1)
df_sentences = pd.DataFrame([sentence for row in preformatted for sentence in row]) # flatted result and convert to dataframe
df_sentences.index = df_sentences.index.rename("sentence_index")

# %% [markdown]
# ### Check DataFrame
#
# Each document will have multiple sentences.  Each row represents a sentence in a document.  The target_class is blank (NaN = not a number = NULL) and the data from this DataFrame is what will be exported to Google docs for manual labling of the "target_class" field.
#
#
# #### Labeling
# - For sentences that don't belong to a target class, no need to update them.
# - Each document should have an entity of interest for:
#    - Purchase price
#    - Due Diligence
#    - Deposit
#    - Others
# -  If a sentence has a purchase price in it, we should label it accordingly.

# %%
df_sentences
# Out:
#                 document_index  \
# sentence_index
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 19762                      337
# 19763                      337
# 19764                      337
# 19765                      337
# 19766                      337
#
#                                                          document  \
# sentence_index
# 0               010 400 Divisadero SHAC LOI 09.10.18.pdf.png.p...
# 1               010 400 Divisadero SHAC LOI 09.10.18.pdf.png.p...
# 2               010 400 Divisadero SHAC LOI 09.10.18.pdf.png.p...
# 3               010 400 Divisadero SHAC LOI 09.10.18.pdf.png.p...
# 4               010 400 Divisadero SHAC LOI 09.10.18.pdf.png.p...
# ...                                                           ...
# 19762                  Waterton LOI 8-28-12.pdf.png.processed.pdf
# 19763                  Waterton LOI 8-28-12.pdf.png.processed.pdf
# 19764                  Waterton LOI 8-28-12.pdf.png.processed.pdf
# 19765                  Waterton LOI 8-28-12.pdf.png.processed.pdf
# 19766                  Waterton LOI 8-28-12.pdf.png.processed.pdf
#
#                                                          sentence  \
# sentence_index
# 0                                                    SUMMERHILL .
# 1                                                               .
# 2               COMMUNITIES OF DISTINCTION September 10, 2018 ...
# 3               Our Experience SummerHill is based in Palo Alt...
# 4               Over the past 40 years, SummerHill has establi...
# ...                                                           ...
# 19762           If you have any questions or if I can be of fu...
# 19763                       Sincerely, Waterton Associates L.L.C.
# 19764                         Mark H. Stem Senior Vice President.
# 19765           Acquisitions Accepted and agreed to this day o...
# 19766                        Seller: By ——————— Its Page 5 of5 4:
#
#                 target_class
# sentence_index
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 19762                    NaN
# 19763                    NaN
# 19764                    NaN
# 19765                    NaN
# 19766                    NaN
#
# [19767 rows x 4 columns]

# %% [markdown]
# ### Write CSV Doc for Google docs

# %%
df_sentences.to_csv("document_sentences.csv", encoding = "utf8")

# %% [markdown]
# ### Tag Sentences Based on Keyword

# %%
# mask1 = df_sentences.sentence.str.contains("price|purchase")
# mask2 = df_sentences.sentence.str.contains("\$")

# df_sentences.loc[(mask1 & mask2), 'target_class'] = "purchase_price"

# %%
# df_sentences[(mask1 & mask2)].values

# %% [markdown]
# ### Use Original Regexes for Matching

# %%
## Original regexs:

dollar_amount               = """\$ {0,}[0-9]{1,3}(,[0-9]{3}){0,}"""
first_dollaramt_insentence  = """([^.])+""" + dollar_amount
numberswrittenout           = """((one|eleven|ten|two|twelve|twenty|three|thirteen|thirty|fourteen|forty|four|fifteen|fifty|five|sixteen|sixty|six|seventeen|seventy|seven|eighteen|eighty|eight|nineteen|ninety|nine|hundred|thousand|million|billion)[- ]{0,1})+"""
time_period                 = """(""" + numberswrittenout +"""|\(?[0-9]{1,3}[) -])+((business|calendar)[ -])?(day|month|week|year)s?"""
first_timeperiod_insentence = """([^.])+""" + time_period
monthsofyear_regex          = """(january|jan\.{0,1}|february|feb\.{0,1}|march|mar\.{0,1}|april|apr\.{0,1}|may|june|jun\.{0,1}|july|jul\.{0,1}|august|aug\.{0,1}|september|sept\.{0,1}|october|oct\.{0,1}|november|nov\.{0,1}|december|dec\.{0,1})"""
date_slashtype_regex        = """(\d{1,2}/\d{1,2}/\d{4})"""
date_writtenout_regex       = """(""" + monthsofyear_regex + """ \d{1,2}, \d{4}""" + """)"""
date_eithertype_regex       = """(""" + date_writtenout_regex + """|""" + date_slashtype_regex + """)"""
first_date_or_timeperiod_insentence = """([^.])+""" + """(""" + time_period + """|""" +date_eithertype_regex + """)"""
deposit_regex               = """((initial|first|second|third|fourth|fifth|sixth|seventh|eighth|ninth|tenth) )?deposit"""
price_regex                 = """((purchase) )?price"""
dd_regex                    = """(dd|due diligence|feasibility|inspection)( period)?"""
closing_regex               = """((closing)( (period|date))?|close of escrow)"""

# %% [markdown]
# ### Sentences per Document Count
#
# Mainly, just want to make sure the original document count matches the original 338.  Looks good.

# %%
df_sentences.document.value_counts()
# Out:
# Essex LOI 9-16-05.pdf.png.processed.pdf                                               361
# Mission Pointe Essex LOI 7-10-06.pdf.png.processed.pdf                                303
# LOI_Pacific Property_091605.pdf.png.processed.pdf                                     178
# Essex LOI - 11.7.2012.pdf.png.processed.pdf                                           170
# 082 Wolff LOI 2015-11-5.pdf.png.processed.pdf                                         167
#                                                                                      ...
# MCIP Villa Morada LOI.pdf.png.processed.pdf                                            16
# Bridgecourt LOI  - Fairstead - 2017-9-14.pdf.png.processed.pdf                         14
# IMT LOI - The Courtyards at 65th Street - 4.18.19.pdf.png.processed.pdf                10
# 032 KB Home VC LOI Alameda Point 8.22.16 COE @ InTract Start.pdf.png.processed.pdf      9
# Related LOI 5-23-08.pdf.png.processed.pdf                                               8
# Name: document, Length: 338, dtype: int64

# %% [markdown]
# ## Labeling

# %% [markdown]
# ### Setting Purchase Price
# Matches all sentences matching purchase price regex pattern.

# %%
## THis one works pretty well, keeping it
mask1 = df_sentences.sentence.str.contains(r"(purchase)?price[^.]+\$ {0,}[0-9]{1,3}(,[0-9]{3}){0,}", flags = re.IGNORECASE, regex = True)
df_sentences.loc[mask1, 'target_class'] = "purchase_price"
# Out:
# /home/dave/anaconda3/envs/bidinterpreter/lib/python3.8/site-packages/pandas/core/strings.py:1954: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %% [markdown]
# ### Setting Deposit

# %%
mask1 = df_sentences.sentence.str.contains(f"(initial|first|second|third|fourth|fifth|sixth|seventh|eighth|ninth|tenth)?deposit[^.]+\$", flags = re.IGNORECASE, regex = True)
df_sentences.loc[mask1, 'target_class'] = "deposit"

# %% [markdown]
# ### Setting Closing

# %%
mask1 = df_sentences.sentence.str.contains(closing_regex + first_date_or_timeperiod_insentence, flags = re.IGNORECASE, regex = True)
df_sentences.loc[mask1, 'target_class'] = "closing"

# %% [markdown]
# ### Setting Due Diligence

# %%
mask1 = df_sentences.sentence.str.contains(dd_regex + first_date_or_timeperiod_insentence, flags = re.IGNORECASE, regex = True)
df_sentences.loc[mask1, 'target_class'] = "dd"
# Out:
# /home/dave/anaconda3/envs/bidinterpreter/lib/python3.8/site-packages/pandas/core/strings.py:1954: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %% [markdown]
# ### Documents Having Lots of False Positive Matches

# %%
df_sentences[~df_sentences['target_class'].isnull()].document.value_counts().head(30)
# Out:
# 032 SARES REGIS LOI 11-7-11.pdf.png.processed.pdf                          11
# 030 SARES REGIS LOI 10-18-11.pdf.png.processed.pdf                          9
# LOI 400 Divusadero 10.19.16.pdf.png.processed.pdf                           8
# 012 Pulte LOI 2016-8-5.pdf.png.processed.pdf                                8
# 051 TrueLife LOI Crescent Heights 2017-11-22.pdf.png.processed.pdf          8
# The Heights LOI_Pulte.pdf.png.processed.pdf                                 7
# 011 Pulte LOI 2016-2-27.pdf.png.processed.pdf                               7
# LOI Caltrain Bldgs 4 and 1.pdf.png.processed.pdf                            7
# 081 Khov LOI Crescent Heights 2017-11-13.pdf.png.processed.pdf              7
# 030 MCRT LOI_400 Divis final_REDLINE 011420.pdf.png.processed.pdf           7
# 170217_Alameda Point 6_7_NWHM  LOI.pdf.png.processed.pdf                    7
# 082 Khov LOI Crescent Heights 2017-11-27.pdf.png.processed.pdf              7
# 010 Pulte LOI 2016-2-12.pdf.png.processed.pdf                               7
# WP LOI 400 Divisadero 2.15.19.pdf.png.processed.pdf                         7
# 050 TrueLife LOI Crescent Heights 2017-11-1.pdf.png.processed.pdf           7
# Comstock LOI 2016-6-2.pdf.png.processed.pdf                                 6
# The Lafayette LOI_Anton_030320.pdf.png.processed.pdf                        6
# 012 DR Horton LOI Crescent Heights 2017-11-8.pdf.png.processed.pdf          6
# CIM LOI - 1880 Mission - 2012 12 06.pdf.png.processed.pdf                   6
# FPA Villa Morada_LOI.pdf.png.processed.pdf                                  6
# 400 Divisadero_Mill Creek LOI comments_020520.pdf.png.processed.pdf         6
# TrueLife LOI Railroad_Hercules.pdf.png.processed.pdf                        6
# 010 DR Horton LOI Crescent Heights 2017-11-1.pdf.png.processed.pdf          6
# Romel LOI 2018-8-9.pdf.png.processed.pdf                                    6
# Romel LOI 8.9.18.pdf.png.processed.pdf                                      6
# Dutchints LOI_VOLAR_350 S Winchester_4.30.19.pdf.png.processed.pdf          6
# 080 Khov LOI Cresent Heights 2017-11-8.pdf.png.processed.pdf                6
# Archstone LOI 9-16-05.pdf.png.processed.pdf                                 6
# WP LOI 400 Divisadero 10.11.19.pdf.png.processed.pdf                        6
# 033 LOI Alameda Point KB Home 9.14.16 HIGHLIGHTED.pdf.png.processed.pdf     6
# Name: document, dtype: int64

# %%
subset = df_sentences[~df_sentences['target_class'].isnull()].document.value_counts()
df_sentences[df_sentences.document.isin(subset[subset > 4].index)].to_csv("documents_with_complex_chunk_varients.csv", encoding = "utf8")

# %%
(subset > 4).sum()
# Out:
# 72

# %%
df
# Out:
#      document_index                                           document  \
# 0                 0  010 400 Divisadero SHAC LOI 09.10.18.pdf.png.p...
# 1                 1  010 AvalonBay LOI - Gateway - 2019-11-7.pdf.pn...
# 2                 2  010 Cambridge Capital LOI 2016-04-07.pdf.png.p...
# 3                 3  010 DR Horton LOI Crescent Heights 2017-11-1.p...
# 4                 4  010 Dutchints LOI 2018-11-17.pdf.png.processed...
# ..              ...                                                ...
# 333             333  Waterford Place JPM LOI 101129.pdf.png.process...
# 334             334  Waterford Place JPM LOI 101202.pdf.png.process...
# 335             335  Waterford Place Signed LOI 12-15-10.pdf.png.pr...
# 336             336  Waterford Place UBS LOI (12.2.2010).pdf.png.pr...
# 337             337         Waterton LOI 8-28-12.pdf.png.processed.pdf
#
#                                                   text  \
# 0    SUMMERHILL . . COMMUNITIES OF DISTINCTION Sept...
# 1    AvalonBay COMMUNITIES November 7, 2019 Hunter ...
# 2    CAMBRIDGE CAPITAL INVESTORS, LLC 1620 Park Vis...
# 3    ll-R-HOHIDN 35% ﬂmer/ca’s W November 1, 2017 B...
# 4    DocuSign E nvelope ID: C431689D-FF59-4CAD-BG34...
# ..                                                 ...
# 333  JPMorgan 0 Asset Management November 30, 2010 ...
# 334  JPMorgan 0 Asset Management December 2, 2010 V...
# 335  UBS Realty Investors LLC UB S Global Asset Man...
# 336  UBS Realty Investors LLC UBS Global Asset Mana...
# 337  Camden Parkside Letter oflntent Tuesday, Augus...
#
#                                             vocabulary
# 0    [{'x0': 182.057, 'x1': 416.573, 'top': 115.213...
# 1    [{'x0': 1293.943, 'x1': 1505.830, 'top': 289.4...
# 2    [{'x0': 556.457, 'x1': 758.058, 'top': 220.534...
# 3    [{'x0': 740.571, 'x1': 956.571, 'top': 173.093...
# 4    [{'x0': 50.400, 'x1': 146.058, 'top': 40.242, ...
# ..                                                 ...
# 333  [{'x0': 691.200, 'x1': 993.601, 'top': 178.809...
# 334  [{'x0': 705.600, 'x1': 1007.999, 'top': 181.36...
# 335  [{'x0': 1192.114, 'x1': 1231.200, 'top': 127.6...
# 336  [{'x0': 1200.343, 'x1': 1241.486, 'top': 84.18...
# 337  [{'x0': 1361.829, 'x1': 1460.571, 'top': 96.87...
#
# [338 rows x 4 columns]

# %% [markdown]
# ### Save Varients to CSV
#
# Relevent Slack thread:
# - https://bid-central.slack.com/archives/C01A261EFGT/p1599251204029700

# %% [markdown]
# ### Saving Labled Sentence Data
#
# This is the datset we will use for our first generation ML models that will predict which types of sentences exist in documents for the relevant entity match algorithms we develop.

# %%
df_sentences.to_csv("./documents_to_sentences_labeled-09-04-2020.csv", encoding="utf8")
